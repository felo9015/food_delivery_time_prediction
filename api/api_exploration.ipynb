# %% [markdown]
# <!-- TODO — próxima etapa: probar la lógica del endpoint celda a celda (cargar el modelo, simular un input, verificar la predicción) antes de envolverla en el endpoint formal de main.py -->
